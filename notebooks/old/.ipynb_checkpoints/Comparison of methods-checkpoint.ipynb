# %% [markdown]
# ## Pretty plotting of results

# %%
using JLD2
include("../../code/headers.jl");

# %%
# Load plot from file
JLD2.@load "../code/test/method_comparison4.jld" pl;
# Out:
# ┌ Warning: Opening file with JLD2.MmapIO failed, falling back to IOStream
# └ @ JLD2 /home/crotti/.julia/packages/JLD2/aRhgS/src/JLD2.jl:196
# SystemError: opening file "../code/test/method_comparison4.jld": No such file or directory
#
# Stacktrace:
#  [1] #systemerror#48 at ./error.jl:167 [inlined]
#  [2] systemerror at ./error.jl:167 [inlined]
#  [3] open(::String; lock::Bool, read::Bool, write::Bool, create::Bool, truncate::Bool, append::Bool) at ./iostream.jl:284
#  [4] openfile at /home/crotti/.julia/packages/JLD2/aRhgS/src/JLD2.jl:186 [inlined]
#  [5] openfile(::Type{T} where T, ::String, ::Bool, ::Bool, ::Bool, ::Type{T} where T) at /home/crotti/.julia/packages/JLD2/aRhgS/src/JLD2.jl:197
#  [6] jldopen(::String, ::Bool, ::Bool, ::Bool, ::Type{JLD2.MmapIO}; fallback::Type{IOStream}, compress::Bool, mmaparrays::Bool) at /home/crotti/.julia/packages/JLD2/aRhgS/src/JLD2.jl:249
#  [7] jldopen(::String, ::Bool, ::Bool, ::Bool, ::Type{JLD2.MmapIO}) at /home/crotti/.julia/packages/JLD2/aRhgS/src/JLD2.jl:213
#  [8] jldopen(::String, ::String; iotype::Type{T} where T, kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /home/crotti/.julia/packages/JLD2/aRhgS/src/JLD2.jl:305
#  [9] jldopen at /home/crotti/.julia/packages/JLD2/aRhgS/src/JLD2.jl:300 [inlined] (repeats 2 times)
#  [10] jldopen(::var"#1#2", ::String; kws::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /home/crotti/.julia/packages/JLD2/aRhgS/src/loadsave.jl:2
#  [11] jldopen(::Function, ::String) at /home/crotti/.julia/packages/JLD2/aRhgS/src/loadsave.jl:2
#  [12] top-level scope at /home/crotti/.julia/packages/JLD2/aRhgS/src/loadsave.jl:144

# %% [markdown]
# Better code that will hopefully work at some point...

# %%
# function zero_codeword(lm::LossyModel)
#     zeros(Int, lm.fg.n)
# end
# JLD2.@load "../code/test/method_comparison3.jld" sims_ms sims_cycles sims_sa

# println("Graph size: ", sims_cycles[1].n, "\n")
# println("Max-sum details: ", sims_ms[1].algo, "Removed factors b=", sims_ms[1].b, "\n")
# println("Simulated annealing details: ", sims_sa[1].algo)

# ms = 3 # marker size
# pl = plot(sims_ms, label="Max-Sum", size=(600,400), legend=:outertopright, dpi=200, ms=ms, marker=:square)
# plot!(pl, sims_cycles, label="Optimal cycle", ms=ms)
# plot!(pl, sims_sa, label="Simulated annealing", ms=ms, marker=:diamond)

# %%
plot!(pl, dpi=200, legend=:topright, size=(400,400))
# Out:
# UndefVarError: plot! not defined
#
# Stacktrace:
#  [1] top-level scope at In[5]:1

# %%
dist_sa = pl[1][end][:y]
# Out:
# UndefVarError: pl not defined
#
# Stacktrace:
#  [1] top-level scope at In[6]:1

# %%
savefig(pl, "method_comparison.png")

# %%
# JLD2.@load "/home/crotti/sourcecoding/code/test/gfq-20210203_1415.jld"
JLD2.@load "/home/crotti/sourcecoding/code/test/gfq-20210205_0122.jld"
# Out:
# 1-element Array{Symbol,1}:
#  :sims_vec

# %%
pl2 = plot(vec(sims_vec[:]), size=(400,400), dpi=200, ms=2)

# %%
savefig(pl2, "gfq.png")

# %% [markdown]
# # RDB with optimal cycles
# ---------------
#
# Use the optimal cycles strategy to compute the optimal curve in the rate-distortion plane

# %%
using JLD2
include("../code/headers.jl");

# %% [markdown]
# Load the results of simulations already run. **Compare with Max-Sum**.
#
# - n = 1260
# - b = n/100
# - maxiter = 200
# - Tmax = 1 (max number of MS trials)

# %%
@load "../code/test/rdb_optimal_cycles2.jld" sims_ms sims_cycles;

# %% [markdown]
# Plot

# %%
pl = plot(sims_ms, label="Max-Sum")
plot!(pl, sims_cycles, label="Optimal cycle", size=(500,500))

# %% [markdown]
# ## FIxed number (b=1) of leaves
# ----------
# - n = 1260
# - b = 1
# - maxiter = 200
# - Tmax = 1 (max number of MS trials)

# %%
@load "../code/test/rdb_optimal_cycles3.jld" sims_ms sims_cycles
pl = plot(sims_ms, label="Max-Sum")
plot!(pl, sims_cycles, label="Optimal cycle", size=(500,500))

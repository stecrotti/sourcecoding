# %%
using ImageMagick, Images, ImageTransformations
im = Gray.(imresize(load("albert.png"), ratio=0.302))
img = Int.(round.(im))
display(imresize(im, ratio=1))
# Out:
# 283×260 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)  …  Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)  …  Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)  …  Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)  …  Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)  …  Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)
#  Gray{N0f8}(0.969)  Gray{N0f8}(0.969)     Gray{N0f8}(0.969)

# %%
y = vcat(img...)
length(y)
# Out:
# 73580

# %%
include("../../code/headers.jl")
q = 2
n = length(y)
R = reverse(0.2:0.2:0.8)
nrates = length(R)
m = Int.(round.(n*(1 .- R)))
seed = 234
algo = OptimalCycle()
# algo = MS(maxiter=1000, gamma=1e-3, sigma=1e-10, Tmax=1)
compressed = [zeros(Int,n) for r in R]

nchunks = 4
@assert mod(n, nchunks)==0
@assert all([mod(mm, nchunks)==0 for mm in m])
chunk_length = div(n, nchunks)
# Out:
# 18395

# %%
# for j in 1:nrates
#     println("-- Rate $j of $nrates: ")
#     lm = LossyModel(Val(q), n, m[j], y=y)
#     res = solve!(lm, algo, randseed=seed, verbose=true, showprogress=true)
#     compressed[j] = lm.x
# end

for j in 1:nrates
    println("-- Rate $j of $nrates: ")
    for c in 1:nchunks
        println("--- Chunk $c of $nchunks")
        lm = LossyModel(Val(q), chunk_length, div(m[j], nchunks), y=y[(c-1)*chunk_length+1:c*chunk_length])
        breduction!(lm,1)
        res = solve!(lm, algo, randseed=seed, verbose=true, showprogress=true)
        compressed[j][(c-1)*chunk_length+1:c*chunk_length] = lm.x
    end
end
# Out:
# -- Rate 1 of 4:
# --- Chunk 1 of 4
# Iter 1. Distortion 0.6625. Cycle weight -7358.0. Energy shift -3679.0
# Iter 2. Distortion 0.4625. Cycle weight -7358.0. Energy shift -3679.0
# Iter 3. Distortion 0.2636. Cycle weight -7318.0. Energy shift -3659.0
# Iter 4. Distortion 0.0954. Cycle weight -6188.0. Energy shift -3094.0
# Iter 5. Distortion 0.0477. Cycle weight -1754.0. Energy shift -877.0
# Iter 6. Distortion 0.0477. Cycle weight -2.0. Energy shift -1.0
# Iter 7. Distortion 0.0477. Cycle weight 0.0. Energy shift 0.0
# --- Chunk 2 of 4
# Iter 1. Distortion 0.6209. Cycle weight -7358.0. Energy shift -3679.0
# Iter 2. Distortion 0.4209. Cycle weight -7358.0. Energy shift -3679.0
# Iter 3. Distortion 0.2257. Cycle weight -7182.0. Energy shift -3591.0
# Iter 4. Distortion 0.0825. Cycle weight -5266.0. Energy shift -2633.0
# Iter 5. Distortion 0.0496. Cycle weight -1212.0. Energy shift -606.0
# Iter 6. Distortion 0.0496. Cycle weight 0.0. Energy shift 0.0
# --- Chunk 3 of 4
# Iter 1. Distortion 0.6903. Cycle weight -7358.0. Energy shift -3679.0
# Iter 2. Distortion 0.4903. Cycle weight -7358.0. Energy shift -3679.0
# Iter 3. Distortion 0.2906. Cycle weight -7348.0. Energy shift -3674.0
# Iter 4. Distortion 0.1096. Cycle weight -6658.0. Energy shift -3329.0
# Iter 5. Distortion 0.0449. Cycle weight -2380.0. Energy shift -1190.0
# Iter 6. Distortion 0.0448. Cycle weight -4.0. Energy shift -2.0
# Iter 7. Distortion 0.0448. Cycle weight 0.0. Energy shift 0.0
# --- Chunk 4 of 4
# Iter 1. Distortion 0.7156. Cycle weight -7358.0. Energy shift -3679.0
# Iter 2. Distortion 0.5156. Cycle weight -7358.0. Energy shift -3679.0
# Iter 3. Distortion 0.3159. Cycle weight -7346.0. Energy shift -3673.0
# Iter 4. Distortion 0.1257. Cycle weight -6998.0. Energy shift -3499.0
# Iter 5. Distortion 0.042. Cycle weight -3078.0. Energy shift -1539.0
# Iter 6. Distortion 0.042. Cycle weight 0.0. Energy shift 0.0
# -- Rate 2 of 4:
# --- Chunk 1 of 4
# Iter 1. Distortion 0.4631. Cycle weight -14696.0. Energy shift -7348.0
# Iter Iter 3. Distortion 0.1231. Cycle weight -438.0. Energy shift -219.0
# Iter 4. Distortion 0.1231. Cycle weight 0.0. Energy shift 0.0
# --- Chunk 2 of 4
# Iter 1. Distortion 0.4223. Cycle weight -14662.0. Energy shift -7331.0
# Iter 2. Distortion 0.1286. Cycle weight -10808.0. Energy shift -5404.0
# Iter 3. Distortion 0.1144. Cycle weight -522.0. Energy shift -261.0
# Iter 4. Distortion 0.1144. Cycle weight 0.0. Energy shift 0.0
# --- Chunk 3 of 4
# Iter 1. Distortion 0.4904. Cycle weight -14714.0. Energy shift -7357.0
# Iter 2. Distortion 0.1406. Cycle weight -12866.0. Energy shift -6433.0
# Iter 3. Distortion 0.1309. Cycle weight -360.0. Energy shift -180.0
# Iter 4. Distortion 0.1309. Cycle weight 0.0. Energy shift 0.0
# --- Chunk 4 of 4
# Iter 1. Distortion 0.5158. Cycle weight -14708.0. Energy shift -7354.0
# Iter 2. Distortion 0.1482. Cycle weight -13524.0. Energy shift -6762.0
# Iter 3. Distortion 0.1415. Cycle weight -248.0. Energy shift -124.0
# Iter 4. Distortion 0.1414. Cycle weight -2.0. Energy shift -1.0
# Iter 5. Distortion 0.1414. Cycle weight 0.0. Energy shift 0.0
# -- Rate 3 of 4:
# --- Chunk 1 of 4
# Iter 1. Distortion 0.2918. Cycle weight -20998.0. Energy shift -10499.0
# Iter 2. Distortion 0.1999. Cycle weight -3378.0. Energy shift -1689.0
# Iter 3. Distortion 0.1997. Cycle weight -8.0. Energy shift -4.0
# Iter 4. Distortion 0.1997. Cycle weight 0.0. Energy shift 0.0
# --- Chunk 2 of 4
# Iter 1. Distortion 0.2722. Cycle weight -20186.0. Energy shift -10093.0
# Iter 2. Distortion 0.1962. Cycle weight -2794.0. Energy shift -1397.0
# Iter 3. Distortion 0.196. Cycle weight -10.0. Energy shift -5.0
# Iter 4. Distortion 0.196. Cycle weight 0.0. Energy shift 0.0
# --- Chunk 3 of 4
# Iter 1. Distortion 0.3097. Cycle weight -21360.0. Energy shift -10680.0
# Iter 2. Distortion 0.2082. Cycle weight -3736.0. Energy shift -1868.0
# Iter 3. Distortion 0.2073. Cycle weight -32.0. Energy shift -16.0
# Iter 4. Distortion 0.2073. Cycle weight 0.0. Energy shift 0.0
# --- Chunk 4 of 4
# Iter 1. Distortion 0.3251. Cycle weight -21722.0. Energy shift -10861.0
# Iter 2. Distortion 0.2109. Cycle weight -4204.0. Energy shift -2102.0
# Iter 3. Distortion 0.2102. Cycle weight -26.0. Energy shift -13.0
# Iter 4. Distortion 0.2102. Cycle weight 0.0. Energy shift 0.0
# -- Rate 4 of 4:
# --- Chunk 1 of 4
# Iter 1. Distortion 0.252. Cycle weight -22462.0. Energy shift -11231.0
# Iter 2. Distortion 0.252. Cycle weight 0.0. Energy shift 0.0
# --- Chunk 2 of 4
# Iter 1. Distortion 0.259. Cycle weight -20670.0. Energy shift -10335.0
# Iter 2. Distortion 0.259. Cycle weight 0.0. Energy shift 0.0
# --- Chunk 3 of 4
# Iter 1. Distortion 0.2482. Cycle weight -23624.0. Energy shift -11812.0
# Iter 2. Distortion 0.2482. Cycle weight 0.0. Energy shift 0.0
# --- Chunk 4 of 4
# Iter 1. Distortion 0.248. Cycle weight -24560.0. Energy shift -12280.0
# Iter 2. Distortion 0.248. Cycle weight 0.0. Energy shift 0.0

# %%
compressed_imgs = [reshape(x, size(im)) for x in compressed]
alberts = imresize(Gray.(hcat(img, compressed_imgs...)), ratio=1)
# Out:
# 283×1300 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)

# %%
using FileIO
save("alberts.png", alberts)
# Out:
# 0
